# %%
import pandas as pd

pd.set_option('display.max_columns', None)

df = pd.read_parquet("data/games_2024_2025_2026.parquet")

# todays_games = df[df["game_date"] == "2026-04-08"]

home_favored = df[
    (df["sp_kbb_diff"] > 3) &
    (df["sp_xfip_diff"] < -0.5) &
    (df["offense_diff"] > 10)
]

away_favored = df[
    (df["sp_kbb_diff"] < -3) &
    (df["sp_xfip_diff"] > 0.5) &
    (df["offense_diff"] < -10)
]

mismatches = pd.concat([home_favored, away_favored])
# mismatches["favored_team"] = mismatches.apply(
#     lambda row: row["home_team_name"] if row["sp_kbb_diff"] > 0 else row["away_team_name"],
#     axis=1
# )

mismatches["favored_home"] = mismatches["sp_kbb_diff"] > 0
mismatches["favored_won"] = (
    (mismatches["favored_home"] & (mismatches["home_win"] == 1)) |
    (~mismatches["favored_home"] & (mismatches["home_win"] == 0))
)

mismatches["game_date"] = pd.to_datetime(mismatches["game_date"])

mismatches["year"] = mismatches["game_date"].dt.year
mismatches["month"] = mismatches["game_date"].dt.month

mismatches[~mismatches["favored_home"]].tail(5)
# Out:
#       game_pk  game_date detailed_state        home_team_name  \
# 5988   824783 2026-04-06          Final        Boston Red Sox
# 5993   824376 2026-04-06          Final      Colorado Rockies
# 5995   823237 2026-04-06          Final  San Francisco Giants
# 6010   823235 2026-04-07          Final  San Francisco Giants
# 6018   823234 2026-04-08    In Progress  San Francisco Giants
#
#              away_team_name  home_score  away_score home_probable_pitcher  \
# 5988      Milwaukee Brewers         6.0         8.0          Brayan Bello
# 5993         Houston Astros         9.0         7.0          Ryan Feltner
# 5995  Philadelphia Phillies         4.0         6.0         Adrian Houser
# 6010  Philadelphia Phillies         6.0         0.0            Robbie Ray
# 6018  Philadelphia Phillies         0.0         0.0           Tyler Mahle
#
#      away_probable_pitcher  home_wrc_plus  away_wrc_plus  home_sp_kbb  \
# 5988      Brandon Woodruff      96.689895     110.191638     0.000000
# 5993           Cody Bolton      97.560976     122.822300     5.714286
# 5995        Andrew Painter      87.833914      99.012776     7.547170
# 6010    Cristopher Sánchez      87.833914      99.012776    17.391304
# 6018            Aaron Nola      87.833914      99.012776    17.777778
#
#       away_sp_kbb  home_sp_xfip  away_sp_xfip  home_win  sp_kbb_diff  \
# 5988    17.391304      5.600000      4.506250       0.0   -17.391304
# 5993    23.333333      4.540000      3.372727       1.0   -17.619048
# 5995    16.666667      2.658824      1.814286       0.0    -9.119497
# 6010    27.536232      3.561538      1.018367       1.0   -10.144928
# 6018    27.659574      4.400000      3.364706       NaN    -9.881797
#
#       sp_xfip_diff  offense_diff  stats_season  favored_home  favored_won  \
# 5988      1.093750    -13.501742          2026         False         True
# 5993      1.167273    -25.261324          2026         False        False
# 5995      0.844538    -11.178862          2026         False         True
# 6010      2.543171    -11.178862          2026         False        False
# 6018      1.035294    -11.178862          2026         False        False
#
#       year  month
# 5988  2026      4
# 5993  2026      4
# 5995  2026      4
# 6010  2026      4
# 6018  2026      4

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

df = pd.read_parquet("data/games_2024_2025_2026.parquet")

todays_games = df[df["game_date"] == "2026-04-09"]

todays_games.tail(25)
# Out:
#       game_pk   game_date detailed_state      home_team_name  \
# 6026   823884  2026-04-09      Scheduled       Miami Marlins
# 6027   823565  2026-04-09      Scheduled    New York Yankees
# 6028   823724  2026-04-09      Scheduled     Minnesota Twins
# 6029   823645  2026-04-09      Scheduled       New York Mets
# 6030   824130  2026-04-09      Scheduled  Kansas City Royals
#
#             away_team_name  home_score  away_score home_probable_pitcher  \
# 6026       Cincinnati Reds         NaN         NaN             Max Meyer
# 6027             Athletics         NaN         NaN         Ryan Weathers
# 6028        Detroit Tigers         NaN         NaN             Mick Abel
# 6029  Arizona Diamondbacks         NaN         NaN          Nolan McLean
# 6030     Chicago White Sox         NaN         NaN             Seth Lugo
#
#      away_probable_pitcher  home_wrc_plus  away_wrc_plus  home_sp_kbb  \
# 6026          Rhett Lowder     105.981417      88.559814    13.636364
# 6027       Jeffrey Springs     104.239257      95.383275    15.789474
# 6028         Jack Flaherty      95.673635      99.448316     0.000000
# 6029     Eduardo Rodriguez     103.077816      91.608595    19.512195
# 6030           Anthony Kay      99.303136      90.011614    17.777778
#
#       away_sp_kbb  home_sp_xfip  away_sp_xfip  home_win  sp_kbb_diff  \
# 6026    11.627907      3.720690      3.736364       NaN     2.008457
# 6027    11.627907      2.225000      2.570588       NaN     4.161567
# 6028     0.000000      4.872727      5.140000       NaN     0.000000
# 6029    10.869565      3.487097      2.516667       NaN     8.642630
# 6030    -2.500000      1.864706      6.877778       NaN    20.277778
#
#       sp_xfip_diff  offense_diff  stats_season
# 6026     -0.015674     17.421603          2026
# 6027     -0.345588      8.855981          2026
# 6028     -0.267273     -3.774681          2026
# 6029      0.970430     11.469222          2026
# 6030     -5.013072      9.291521          2026
